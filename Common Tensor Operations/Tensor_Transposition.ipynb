# %%
# 1. buat matrix X dengan ukuran 2x3 menggunakan numpy
import numpy as np
import torch
import tensorflow as tf

# %%
x = np.array([[23, 13], [17, 24], [67, 11]])
x
# Out:
# array([[23, 13],
#        [17, 24],
#        [67, 11]])

# %%
# buat matrix X_pt dengan ukuran 2x3 menggunakan pytorch
x_pt = torch.tensor([[23, 13], [17, 24], [67, 11]])
x_pt
# Out:
# tensor([[23, 13],
#         [17, 24],
#         [67, 11]])

# %%
# buat matrix X_tf dengan ukuran 2x3 menggunakan tensorflow
x_tf = tf.Variable([[23, 13], [17, 24], [67, 11]])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=int32, numpy=
# array([[23, 13],
#        [17, 24],
#        [67, 11]], dtype=int32)>

# %%
# 2. lakukan transpose pada matrix X, X_pt dan X_tf

# %% [markdown]
# Numpy

# %%
x.T
# Out:
# array([[23, 17, 67],
#        [13, 24, 11]])

# %% [markdown]
# Torch

# %%
x_pt.T
# Out:
# tensor([[23, 17, 67],
#         [13, 24, 11]])

# %% [markdown]
# TensorFlow

# %%
tf.transpose(x_tf)
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[23, 17, 67],
#        [13, 24, 11]], dtype=int32)>
