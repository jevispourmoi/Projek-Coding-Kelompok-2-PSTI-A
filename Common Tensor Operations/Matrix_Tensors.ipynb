# %%
import numpy as np

# %%
# buat matrix X berukuran 2x3 menggunakan numpy
X = np.array([[62, 26, 15], [61, 15, 25]])
X
# Out:
# array([[62, 26, 15],
#        [61, 15, 25]])

# %%
# tampilkan ukuran dari matrix X
print("shape:", X.shape)
# Out:
# shape: (2, 3)

# %%
# tampilkan ukuran dari matrix X
print("size:", X.size)
# Out:
# size: 6

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
print("kolom pertama:", X[:,0])
# Out:
# kolom pertama: [62 61]

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X
print("baris kedua:", X[1,:])
# Out:
# baris kedua: [61 15 25]

# %%
#ulangi soal nomor 1 menggunakan pytorch
import torch

# %%
X_pt = torch.tensor([[62, 26, 15], [61, 15, 25]])
X_pt
# Out:
# tensor([[62, 26, 15],
#         [61, 15, 25]])

# %%
X_pt.shape # pythonic relative to TensorFlow
# Out:
# torch.Size([2, 3])

# %%
torch.Size([2, 3])
# Out:
# torch.Size([2, 3])

# %%
X_pt[1,:] # N.B.: Python is zero-indexed; written algebra is one-indexed
# Out:
# tensor([61, 15, 25])

# %%
#ulangi soal nomor 1 menggunakan tensorflow
import tensorflow as tf

# %%
X_tf = tf.Variable([[62, 26, 15], [61, 15, 25]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[62, 26, 15],
#        [61, 15, 25]], dtype=int32)>

# %%
tf.rank(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=2>

# %%
tf.shape(X_tf)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([2, 3], dtype=int32)>

# %%
X_tf[1,:]
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([61, 15, 25], dtype=int32)>
