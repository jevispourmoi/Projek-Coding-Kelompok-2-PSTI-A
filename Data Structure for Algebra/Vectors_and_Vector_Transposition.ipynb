# %%
import numpy as np

# %%
# buat vector x dengan ukuran 3x1
x = np.array([54, 5, 4])
print("Vektor x 3x1 :", x)
# Out:
# Vektor x 3x1 : [54  5  4]

# %%
# hitung panjang vector x
print("Panjang vektor x :", len(x))
# Out:
# Panjang vektor x : 3

# %%
# tampilkan ukuran vector x
print("Ukuran vektor x :", x.shape)
# Out:
# Ukuran vektor x : (3,)

# %%
# tampilkan tipe data dari vector x
print("Tipe data vektor x :",type (x))
# Out:
# Tipe data vektor x : <class 'numpy.ndarray'>

# %%
# akses elemen pertama dari vector x
print("Elemen pertama vektor x :", x[0])
# Out:
# Elemen pertama vektor x : 54

# %%
# tampilkan tipe data elemen pertama dari vector x
print("Tipe data elemen pertama vektor x :", type (x[0]))
# Out:
# Tipe data elemen pertama vektor x : <class 'numpy.int64'>

# %%
# lakukan transpose pada vector x dan simpan pada variabel x_t
x_t = x.T
print("Transpose dari vektor x :", x_t)
# Out:
# Transpose dari vektor x : [54  5  4]

# %%
# tampilkan ukuran dari vector x_t
print("Ukuran Transpose x :", x_t.shape)
# Out:
# Ukuran Transpose x : (3,)

# %%
# buat vector y dengan ukuran 3x1
y = np.array([[45, 4, 5]])
print("Vektor y 3x1 :", y)
# Out:
# Vektor y 3x1 : [[45  4  5]]

# %%
# lakukan transpose pada vector y dan simpan pada variabel y_t
y_t = y.T
print("Transpose dari vektor y :", y_t)
# Out:
# Transpose dari vektor y : [[45]
#  [ 4]
#  [ 5]]

# %%
# tampilkan ukuran dari vector y_t
print("Ukuran vektor y_t :", y_t.shape)
# Out:
# Ukuran vektor y_t : (3, 1)

# %%
# lakukan soal nomor 2 menggunakan pytorch dan tensorflow
import torch
import tensorflow as tf

# %%
y_pt = torch.tensor([54, 61, 4])
print("Angka variabel y_pt :", y_pt)
# Out:
# Angka variabel y_pt : tensor([54, 61,  4])

# %%
y_tf = tf.Variable([61, 5, 4])
print("Angka variabel y_tf :", y_tf)
# Out:
# Angka variabel y_tf : <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([61,  5,  4], dtype=int32)>

# %%
# lakukan transpose pada vector y_pt dan simpan pada variabel y_pt_t
y_pt_t == y_pt.T
print("Transpose vektor y_pt :", y_pt.T)
# Out:
# Transpose vektor y_pt : tensor([54, 61,  4])

# %%
# lakukan transpose pada vector y_tf dan simpan pada variabel y_tf_t
y_tf_t = tf.transpose(y_tf)
print("Transpose vektor y_tf :", y_tf_t)
# Out:
# Transpose vektor y_tf : tf.Tensor([61  5  4], shape=(3,), dtype=int32)

# %%
# tampilkan ukuran dari vector y_pt_t
print("Ukuran Vektor y_pt_t :", y_pt_t.shape)
# Out:
# Ukuran Vektor y_pt_t : torch.Size([3])

# %%
# tampilkan ukuran dari vector x_tf_t
print("Ukuran Vektor y_pt_t :", y_tf_t.shape)
# Out:
# Ukuran Vektor y_pt_t : (3,)
