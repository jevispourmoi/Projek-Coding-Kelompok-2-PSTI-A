# %%
# buat variabel skalar x dan simpan suatu nilai skalar
x = 1054
print("Skalar x adalah :", x)
# Out:
# Skalar x adalah : 1054

# %%
# tampilkan tipe data dari x
print("Type data skalar x :", type (x))
# Out:
# Type data skalar x : <class 'int'>

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y = 4501
print("Skalar y adalah :", y)
# Out:
# Skalar y adalah : 4501

# %%
# tampilkan tipe data dari y
print("Type data skalar x :", type (y))
# Out:
# Type data skalar x : <class 'int'>

# %%
# jumlahkan x+y
py_sum = x + y
print("Hasil penjumlahan skalar x dan y adalah :", py_sum)
# Out:
# Hasil penjumlahan skalar x dan y adalah : 5555

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 10.54
print("angka variabel x_float adalah :", x_float)
# Out:
# angka variabel x_float adalah : 10.54

# %%
# jumlahkan x_float dengan y
float_sum = x_float + y
print("Hasil penjumlahan x_float dan y adalah :", float_sum)
# Out:
# Hasil penjumlahan x_float dan y adalah : 4511.54

# %%
# tampilkan tipe data dari x_float
print("Type data x_float :", type (x_float))
# Out:
# Type data x_float : <class 'float'>

# %%
import tensorflow as tf

# %%
# buat variabel tensorflow x dan simpan suatu nilai tensorflow
x_tf = tf.Variable (1054, dtype=tf.float32)
print("angka variabel tensorflow x :",  x_tf)
# Out:
# angka variabel tensorflow x : <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=1054.0>

# %%
# buat variabel tensorflow y dan simpan suatu nilai tensorflow
y_tf = tf.Variable(4501, dtype=tf.float32)
print("angka variabel tensorflow y :",  y_tf)
# Out:
# angka variabel tensorflow y : <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=4501.0>

# %%
# jumlahkan x+y
tf_sum = tf.add(x_tf, y_tf)
print("Hasil penjumlahan x_tf dan y_tf adalah :", tf_sum)
# Out:
# Hasil penjumlahan x_tf dan y_tf adalah : tf.Tensor(5555.0, shape=(), dtype=float32)

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float_tf = tf.Variable (10.54, dytpe=tf.float32)
print("angka variabel x_float_tf :",  x_float_tf)
# Out:
# angka variabel x_float_tf : <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=10.539999961853027>

# %%
# jumlahkan x_float dengan y
tf_sum = tf.add(x_float_tf, y_tf)
print("Hasil penjumlahan x_float_tf dan y_tf adalah :", tf_sum)
# Out:
# Hasil penjumlahan x_float_tf dan y_tf adalah : tf.Tensor(4511.54, shape=(), dtype=float32)

# %%
import torch

# %%
# buat variabel pytorch x dan simpan suatu nilai pytorch
x_pt = torch.tensor(1054)
print("angka variabel pytorch x :",  x_pt)
# Out:
# angka variabel pytorch x : tensor(1054)

# %%
# tampilkan tipe data dari x
print("Type data skalar x :", type (x_pt))
# Out:
# Type data skalar x : <class 'torch.Tensor'>

# %%
# buat variabel pytorch y dan simpan suatu nilai pytorch
y_pt = torch.tensor(4501)
print("angka variabel pytorch y :",  y_pt)
# Out:
# angka variabel pytorch y : tensor(4501)

# %%
# tampilkan tipe data dari y
print("Type data skalar x :", type (y_pt))
# Out:
# Type data skalar x : <class 'torch.Tensor'>

# %%
# jumlahkan x+y
pt_sum = x_pt + y_pt
print("Hasil penjumlahan x_pt dan y_pt adalah :", pt_sum)
# Out:
# Hasil penjumlahan x_pt dan y_pt adalah : tensor(5555)

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float_pt = torch.tensor(10.54)
print("angka variabel x_float_pt :", x_float_pt)
# Out:
# angka variabel x_float_pt : tensor(10.5400)

# %%
# jumlahkan x_float dengan y
pt_sum = x_float_pt + y_pt
print("Hasil penjumlahan x_float_pt dan y_pt adalah :", pt_sum)
# Out:
# Hasil penjumlahan x_float_pt dan y_pt adalah : tensor(4511.5400)

# %%
# tampilkan tipe data dari x_float
print("type data x_float :", type (x_float_pt))
# Out:
# type data x_float : <class 'torch.Tensor'>
