# %% [markdown]
# menyelesaikan soal tranpos menggunakan numpy

# %%
# selesaikan soal berikut
import numpy as np

# %%
p = np.array([[25], [2], [-3], [-23]])
p
# Out:
# array([[ 25],
#        [  2],
#        [ -3],
#        [-23]])

# %%
p_t = p.T
p_t
# Out:
# array([[ 25,   2,  -3, -23]])
